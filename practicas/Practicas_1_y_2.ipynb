# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPabloUM/Probabilidad-y-estadistica/blob/main/practicas/Practicas_1_y_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Probabilidad y estadistica
#
# ## unidad 1
#
# ## Grupo: **2z**
#
# ### Practica 1 y 2. Estadística descriptiva básica e Histogramas y Máximo, mínimo, Rango y dispersión de datos
#
# Alumno:Juan Pablo Urrutia Medrano
#
# Docente: Dr: Jose Gabriel Rodriguez Rivas

# %% [markdown]
# # **Lista de calificaciones**

# %%
from statistics import*

#lista de calificaciones del grupo a de probabilidad y estadistica

grupoa = [70, 70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)

[70,70,65,90,100,95,45,80,73,20,100,96]

#La funcion type nos devuelve el tipo de dato de la variable
type(grupoa)

#sacar la media de las calificaciones con una formula

promedio = sum(grupoa) / len(grupoa)
print(promedio)

#utilizar la funcion mean que esta en la libreria statistics para sacar
#el promedio

promedio2 = mean(grupoa)
print(promedio2)

#Determine el valor de la mediana con la funcion median
mediana = median(grupoa)
print(mediana)

#Dtermine el valor de la moda con la funcion mode

moda = mode(grupoa)
print(moda)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70

# %% [markdown]
# # **Tiempos de 100 metros**

# %%
#definimos una variable llamada tiempos100mts

tiempos100mts = [ 15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]

print(tiempos100mts)

print("El tiempo promedio de los corredores es=>",mean(tiempos100mts))

mediana = median(tiempos100mts)
print("La mediana de los tiempos es=>",mediana)

moda = mode(tiempos100mts)
print("La moda de los tiempos es=>",moda)

multimodas = multimode(tiempos100mts)
print("La moda de los tiempos es=>",multimodas)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# El tiempo promedio de los corredores es=> 17.322
# La mediana de los tiempos es=> 17.2
# La moda de los tiempos es=> 15.1
# La moda de los tiempos es=> [15.1, 17.2]

# %% [markdown]
# # **Fabrica 1**

# %%
# Librería para generar numeros aleatorios
import random


fabrica1 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)

print(fabrica1)
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("La media es= ",media1)
print("La medriana es= ",mediana1)
print("La moda es =",moda1)
# Out:
# [79.53, 87.79, 74.26, 66.84, 68.21, 90.56, 64.26, 83.9, 94.65, 66.53, 77.67, 72.11, 65.16, 67.61, 81.6, 92.83, 76.64, 79.88, 93.9, 96.13, 75.82, 68.7, 89.77, 93.47, 70.58, 69.71, 51.21, 59.65, 93.68, 78.03, 75.38, 85.41, 70.51, 80.13, 99.91, 67.8, 92.57, 74.72, 62.68, 93.52, 92.95, 60.21, 91.51, 86.1, 99.97, 71.49, 91.76, 87.63, 78.66, 86.58, 57.3, 71.29, 84.26, 51.23, 94.59, 65.37, 69.42, 90.34, 96.17, 83.98, 87.55, 70.8, 90.94, 78.18, 98.23, 98.55, 74.03, 94.12, 95.23, 97.67, 72.59, 50.58, 97.77, 78.89, 97.68, 77.27, 67.96, 71.26, 54.08, 56.69, 84.35, 52.3, 70.58, 96.06, 85.61, 77.2, 56.01, 58.6, 98.96, 59.82, 62.34, 53.25, 56.32, 71.59, 96.22, 88.24, 80.64, 65.63, 95.07, 90.97]
# Valores de la fabrica 1
# La media es=  78.5395
# La medriana es=  78.42
# La moda es = 70.58

# %% [markdown]
# # **Fabrica 2**

# %%
# Librería para generar numeros aleatorios
import random


fabrica2 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica2.append(numero_aleatorio)

print(fabrica2)
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("La media es= ",media2)
print("La medriana es= ",mediana2)
print("La moda es =",moda2)
# Out:
# [69.79, 56.73, 55.45, 98.13, 72.32, 61.26, 62.21, 71.35, 50.61, 87.05, 73.09, 68.98, 95.91, 75.29, 91.58, 92.6, 63.09, 75.46, 95.69, 82.27, 59.25, 59.86, 84.7, 51.94, 59.92, 81.32, 72.38, 84.18, 57.36, 72.95, 90.21, 55.6, 80.99, 94.72, 71.51, 91.58, 98.61, 52.03, 93.98, 70.48, 94.84, 97.47, 55.42, 78.44, 94.64, 62.35, 92.02, 77.26, 79.48, 69.18, 73.18, 81.86, 77.76, 55.4, 96.72, 54.67, 99.22, 64.07, 53.98, 73.72, 78.98, 76.79, 69.05, 71.59, 78.08, 71.02, 52.57, 54.64, 82.45, 54.42, 50.52, 93.06, 79.16, 75.96, 97.87, 90.2, 59.72, 74.77, 64.15, 63.97, 51.82, 87.05, 81.77, 93.97, 62.95, 75.27, 67.35, 80.82, 54.44, 77.24, 66.94, 94.05, 90.72, 56.68, 50.7, 52.15, 67.49, 92.15, 92.18, 64.26]
# Valores de la fabrica 2
# La media es=  74.1308
# La medriana es=  73.45
# La moda es = 87.05

# %% [markdown]
# # **Histrogramas Fabrica 1 y 2**

# %%
# librería de python para graficar valores
import matplotlib.pyplot as plt


plt.hist(fabrica1)
plt.title("Producción diaria de la fábrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diara de la fábrica 1')

# %%
plt.hist(fabrica2)
plt.title("Producción diaria de la fábrica 2")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fábrica 2')

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
