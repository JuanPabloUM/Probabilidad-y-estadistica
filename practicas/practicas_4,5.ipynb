# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPabloUM/Probabilidad-y-estadistica/blob/main/practicas/practicas_4%2C5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Probabilidad y estadistica
#
# ## unidad 1
#
# ## Grupo: **2z**
#
# ### Practica 4 y 5. Tabla de frecuencias y regla de Sturges, Diagramas de Cajas y bigotes.
#
# Alumno:Juan Pablo Urrutia Medrano
#
# Docente: Dr: Jose Gabriel Rodriguez Rivas

# %%
import random
#Creamos una lista vacia de 100 personas
edades = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 18, 70)
  #agregamos ell numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [18, 59, 58, 59, 62, 24, 48, 57, 43, 60, 57, 39, 29, 34, 64, 21, 45, 39, 33, 61, 28, 43, 20, 38, 46, 51, 50, 70, 69, 67, 63, 60, 29, 57, 54, 65, 39, 27, 61, 32, 47, 40, 32, 25, 54, 66, 39, 26, 68, 23, 30, 49, 67, 65, 31, 37, 54, 33, 18, 66, 33, 45, 55, 30, 48, 46, 46, 27, 19, 35, 50, 61, 29, 61, 32, 56, 70, 45, 20, 69, 33, 57, 49, 38, 46, 48, 59, 53, 64, 26, 40, 62, 54, 49, 33, 35, 66, 55, 66, 66]

# %%
import pandas as pd
df = pd.DataFrame(edades,columns =['Edad'])
df.head()
# Out:
#    Edad
# 0    18
# 1    59
# 2    58
# 3    59
# 4    62

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("Tabla de la Distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de la Distribucion de frecuencias:
#     Edad  Frecuencia
# 16    18           2
# 34    19           1
# 30    20           2
# 39    21           1
# 40    23           1
# 31    24           1
# 44    25           1
# 18    26           2
# 15    27           2
# 38    28           1
# 9     29           3
# 19    30           2
# 37    31           1
# 11    32           3
# 1     33           5
# 43    34           1
# 21    35           2
# 36    37           1
# 29    38           2
# 6     39           4
# 17    40           2
# 27    43           2
# 12    45           3
# 3     46           4
# 45    47           1
# 8     48           3
# 7     49           3
# 24    50           2
# 42    51           1
# 46    53           1
# 5     54           4
# 20    55           2
# 32    56           1
# 4     57           4
# 33    58           1
# 10    59           3
# 28    60           2
# 2     61           4
# 26    62           2
# 35    63           1
# 25    64           2
# 14    65           2
# 0     66           5
# 13    67           2
# 41    68           1
# 22    69           2
# 23    70           2

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa
# 16    18           2           0.02
# 34    19           1           0.01
# 30    20           2           0.02
# 39    21           1           0.01
# 40    23           1           0.01
# 31    24           1           0.01
# 44    25           1           0.01
# 18    26           2           0.02
# 15    27           2           0.02
# 38    28           1           0.01
# 9     29           3           0.03
# 19    30           2           0.02
# 37    31           1           0.01
# 11    32           3           0.03
# 1     33           5           0.05
# 43    34           1           0.01
# 21    35           2           0.02
# 36    37           1           0.01
# 29    38           2           0.02
# 6     39           4           0.04
# 17    40           2           0.02
# 27    43           2           0.02
# 12    45           3           0.03
# 3     46           4           0.04
# 45    47           1           0.01
# 8     48           3           0.03
# 7     49           3           0.03
# 24    50           2           0.02
# 42    51           1           0.01
# 46    53           1           0.01
# 5     54           4           0.04
# 20    55           2           0.02
# 32    56           1           0.01
# 4     57           4           0.04
# 33    58           1           0.01
# 10    59           3           0.03
# 28    60           2           0.02
# 2     61           4           0.04
# 26    62           2           0.02
# 35    63           1           0.01
# 25    64           2           0.02
# 14    65           2           0.02
# 0     66           5           0.05
# 13    67           2           0.02
# 41    68           1           0.01
# 22    69           2           0.02
# 23    70           2           0.02

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Fr
d.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     18
# 1     59
# 2     58
# 3     59
# 4     62
# ..   ...
# 95    35
# 96    66
# 97    55
# 98    66
# 99    66
#
# [100 rows x 1 columns]

# %%
n = len (edades)
k = int (1 + math.log2(100))
print ("Valor de n = ",n, "\nNumero de intervalos =",k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
tabla_frecuencias = pd.cut (df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase','frec']
tabla_frecuencias
# Out:
#               clase  frec
# 0  (32.857, 40.286]    17
# 1  (55.143, 62.571]    17
# 2    (62.571, 70.0]    17
# 3  (47.714, 55.143]    16
# 4  (25.429, 32.857]    14
# 5  (40.286, 47.714]    10
# 6  (17.947, 25.429]     9

# %%
tabla_frecuencias = tabla_frecuencias.sort_values( by='clase')
tabla_frecuencias
# Out:
#               clase  frec
# 6  (17.947, 25.429]     9
# 4  (25.429, 32.857]    14
# 0  (32.857, 40.286]    17
# 5  (40.286, 47.714]    10
# 3  (47.714, 55.143]    16
# 1  (55.143, 62.571]    17
# 2    (62.571, 70.0]    17

# %%
tabla_frecuencias['frec Rel']= tabla_frecuencias['frec']/n
tabla_frecuencias['frec Porc']= tabla_frecuencias['frec']/n* 100
tabla_frecuencias['frec Ac']= tabla_frecuencias['frec'].cumsum()
tabla_frecuencias['frec Rel Ac']= tabla_frecuencias['frec Porc'].cumsum()
tabla_frecuencias['frec Porc Ac']= tabla_frecuencias['frec Porc'].cumsum()
print("Tabla de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de frecuencias:
#               clase  frec  frec Rel  frec Porc  frec Ac  frec Rel Ac  \
# 6  (17.947, 25.429]     9      0.09        9.0        9          9.0
# 4  (25.429, 32.857]    14      0.14       14.0       23         23.0
# 0  (32.857, 40.286]    17      0.17       17.0       40         40.0
# 5  (40.286, 47.714]    10      0.10       10.0       50         50.0
# 3  (47.714, 55.143]    16      0.16       16.0       66         66.0
# 1  (55.143, 62.571]    17      0.17       17.0       83         83.0
# 2    (62.571, 70.0]    17      0.17       17.0      100        100.0
#
#    frec Porc Ac
# 6           9.0
# 4          23.0
# 0          40.0
# 5          50.0
# 3          66.0
# 1          83.0
# 2         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5,bins=20)
plt.title("Histrograma de edades basado en la funcion de matplotib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histrograma de edades basado en la funcion de matplotib con valores estandar')

# %%
plt.hist(df['Edad'],bins=k,alpha=0.5)
plt.title('Histograma de edades basado en la regla de sturges')
plt.xlabel('edades')
plt.xlabel('frecuencia')
# Out:
# Text(0.5, 0, 'frecuencia')

# %% [markdown]
# Practica 5 Diagrama de cajas y bigotes

# %%
#Creamos una lista vacia de 100 personas
edades2 = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 20, 87)
  #agregamos ell numero aleatorio a la lista de valores
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [86, 33, 70, 75, 79, 30, 28, 40, 38, 79, 62, 51, 21, 35, 65, 73, 78, 37, 63, 55, 50, 37, 69, 82, 28, 64, 24, 41, 57, 87, 54, 60, 74, 53, 77, 71, 56, 54, 77, 74, 47, 83, 69, 75, 69, 22, 65, 50, 84, 59, 42, 28, 39, 54, 40, 82, 85, 69, 64, 50, 62, 29, 86, 52, 54, 34, 65, 64, 59, 20, 29, 47, 27, 42, 59, 30, 46, 73, 42, 39, 21, 66, 48, 40, 28, 20, 75, 81, 24, 20, 42, 35, 36, 83, 34, 86, 81, 55, 26, 20]

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
